# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import seaborn as sns
# %matplotlib inline

# %%
def upload(fileName):
    df = pd.read_csv(fileName)
    return df

# %%
firearm_intersection = upload('fiream_data_intersections13to17.csv')

# %%
firearm_address = upload('FirearmAddress.csv')

# %%
firearm_general = upload('FirearmsData.csv')

# %%
jan_firearm_auction = upload('Jan2021FirearmsAuction.csv')

# %%
firearm_intersection.columns
# Out:
# Index(['incident_number', 'ucr_category', 'type_of_firearm',
#        'firearm_manufacturer', 'firearm_model', 'firearm_caliber',
#        'recovery_date', 'address_geocode_type', 'recovery_block_address',
#        'city', 'state', 'recovery_zipcode', 'person_recovered_from_race',
#        'person_recovered_from_sex', 'person_recovered_from_age',
#        'address_concat', 'x', 'y', 'longitude', 'latitude', 'confidence',
#        'source'],
#       dtype='object')

# %%
firearm_address.columns
# Out:
# Index(['INCIDENT_NUMBER', 'UCR_CATEGORY', 'TYPE_OF_FIREARM',
#        'FIREARM_MANUFACTURER', 'FIREARM_MODEL', 'FIREARM_CALIBER',
#        'RECOVERY_DATE', 'ADDRESS_GEOCODE_TYPE', 'RECOVERY__ADDRESS', 'CITY',
#        'state', 'RECOVERY_ZIPCODE', 'PERSON_RECOVERED_FROM_RACE',
#        'PERSON_RECOVERED_FROM_SEX', 'PERSON_RECOVERED_FROM_AGE',
#        'Address_Concat', 'Longitude', 'Latitude', 'Confidence', 'Source'],
#       dtype='object')

# %%
firearm_general.columns
# Out:
# Index(['INCIDENT_NUMBER', 'UCR_CATEGORY', 'TYPE_OF_FIREARM',
#        'FIREARM_MANUFACTURER', 'FIREARM_MODEL', 'FIREARM_CALIBER',
#        'RECOVERY_DATE', 'RECOVERY_BLOCK_ADDRESS', 'CITY', 'state',
#        'RECOVERY_ZIPCODE', 'PERSON_RECOVERED_FROM_RACE',
#        'PERSON_RECOVERED_FROM_SEX', 'PERSON_RECOVERED_FROM_AGE', 'year'],
#       dtype='object')

# %% [markdown]
# After an initial look at the data, they seem to contain multiples of the same data. I am going to transfer the file names to the same case then merge.

# %%
firearm_address.columns = ['incident_number',
                          'ucr_category',
                          'type_of_firearm',
                          'firearm_manufacturer',
                          'firearm_model',
                          'firearm_caliber',
                          'recovery_date',
                          'address_geocode_type',
                          'recovery_address',
                          'city',
                          'state',
                          'recovery_zipcode',
                          'person_recovered_from_race',
                          'person_recovered_from_sex',
                          'person_recovered_from_age',
                          'address_concat',
                          'longitude',
                          'latitude',
                          'confidence',
                          'source']

# %%
firearm_general.columns = ['incident_number',
                          'ucr_category',
                          'type_of_firearm',
                          'firearm_manufacturer',
                          'firearm_model',
                          'firearm_caliber',
                          'recovery_date',
                          'recovery_block_address',
                          'city',
                          'state',
                          'recovery_zipcode',
                          'person_recovered_from_race',
                          'person_recovered_from_sex',
                          'person_recovered_from_age',
                          'year']

# %%
firearm_address.columns
# Out:
# Index(['incident_number', 'ucr_category', 'type_of_firearm',
#        'firearm_manufacturer', 'firearm_model', 'firearm_caliber',
#        'recovery_date', 'address_geocode_type', 'recovery_address', 'city',
#        'state', 'recovery_zipcode', 'person_recovered_from_race',
#        'person_recovered_from_sex', 'person_recovered_from_age',
#        'address_concat', 'longitude', 'latitude', 'confidence', 'source'],
#       dtype='object')

# %%
firearm_general.columns
# Out:
# Index(['incident_number', 'ucr_category', 'type_of_firearm',
#        'firearm_manufacturer', 'firearm_model', 'firearm_caliber',
#        'recovery_date', 'recovery_block_address', 'city', 'state',
#        'recovery_zipcode', 'person_recovered_from_race',
#        'person_recovered_from_sex', 'person_recovered_from_age', 'year'],
#       dtype='object')

# %%
firearm_intersection.columns
# Out:
# Index(['incident_number', 'ucr_category', 'type_of_firearm',
#        'firearm_manufacturer', 'firearm_model', 'firearm_caliber',
#        'recovery_date', 'address_geocode_type', 'recovery_block_address',
#        'city', 'state', 'recovery_zipcode', 'person_recovered_from_race',
#        'person_recovered_from_sex', 'person_recovered_from_age',
#        'address_concat', 'x', 'y', 'longitude', 'latitude', 'confidence',
#        'source'],
#       dtype='object')

# %%
firearm_half = pd.concat([firearm_address, firearm_intersection], ignore_index = True, axis=0)

# %%
firearm_half.head()
# Out:
#   incident_number        ucr_category         type_of_firearm  \
# 0    80-10-011494  Wpns Law Violation  Pistol, Semi-automatic
# 1    80-10-011506           Narcotics    Shotgun, Pump Action
# 2    80-10-011506           Narcotics    Shotgun, Pump Action
# 3    80-10-011506           Narcotics    Shotgun, Pump Action
# 4    80-10-011506           Narcotics    Shotgun, Pump Action
#
#   firearm_manufacturer   firearm_model firearm_caliber         recovery_date  \
# 0         Manurin S.A.             NaN            765M  2010-02-17T00:00:00Z
# 1       Remington Arms  Shotgun: Model            20GA  2010-02-17T00:00:00Z
# 2       Remington Arms  Shotgun: Model            20GA  2010-02-17T00:00:00Z
# 3       Remington Arms  Shotgun: Model            20GA  2010-02-17T00:00:00Z
# 4       Remington Arms  Shotgun: Model            20GA  2010-02-17T00:00:00Z
#
#   address_geocode_type    recovery_address        city  ...  \
# 0                BLOCK  9400 National Tpke  Louisville  ...
# 1                BLOCK    4500 Landside Dr  Louisville  ...
# 2                BLOCK    4500 Landside Dr  Louisville  ...
# 3                BLOCK    4500 Landside Dr  Louisville  ...
# 4                BLOCK    4500 Landside Dr  Louisville  ...
#
#   person_recovered_from_sex  person_recovered_from_age  \
# 0                         M                       44.0
# 1                         M                       19.0
# 2                         M                       19.0
# 3                         M                       19.0
# 4                         M                       19.0
#
#                            address_concat  longitude   latitude confidence  \
# 0  9400 National Tpke Louisville KY 40118 -85.752898  38.125321       0.54
# 1    4500 Landside Dr Louisville KY 40220 -85.620998  38.198673       1.00
# 2    4500 Landside Dr Louisville KY 40220 -85.620998  38.198673       1.00
# 3    4500 Landside Dr Louisville KY 40220 -85.620998  38.198673       1.00
# 4    4500 Landside Dr Louisville KY 40220 -85.620998  38.198673       1.00
#
#           source  recovery_block_address   x   y
# 0  openaddresses                     NaN NaN NaN
# 1  openaddresses                     NaN NaN NaN
# 2  openaddresses                     NaN NaN NaN
# 3  openaddresses                     NaN NaN NaN
# 4  openaddresses                     NaN NaN NaN
#
# [5 rows x 23 columns]

# %%
firearm_intersection
# Out:
#      incident_number        ucr_category  \
# 0       80-13-097166           Narcotics
# 1       80-11-044948  Wpns Law Violation
# 2       80-11-037378           Narcotics
# 3       80-12-061676  Wpns Law Violation
# 4       80-12-010689           Narcotics
# ...              ...                 ...
# 2741    80-13-089244  Wpns Law Violation
# 2742    80-12-085476  Wpns Law Violation
# 2743    80-16-075482  Wpns Law Violation
# 2744    80-10-073277  Wpns Law Violation
# 2745    80-16-021321  Aggravated Assault
#
#                                         type_of_firearm  \
# 0     Pistol, Semi-automatic                        ...
# 1     Pistol, Semi-automatic                        ...
# 2     Rifle, Semi-automatic                         ...
# 3     Pistol, Revolver                              ...
# 4                                                  Null
# ...                                                 ...
# 2741  Rifle, Single-shot                            ...
# 2742  Pistol, Semi-automatic                        ...
# 2743  Pistol, Semi-automatic                        ...
# 2744  Pistol, Revolver                              ...
# 2745  Pistol, Semi-automatic                        ...
#
#                                    firearm_manufacturer    firearm_model  \
# 0                                                 Ruger             Sr9c
# 1                                              Intratec              NaN
# 2                                               Norinco              Sks
# 3                                                   NaN              NaN
# 4                                                   NaN        Airmaster
# ...                                                 ...              ...
# 2741                                Marlin Firearms Co.              NaN
# 2742                                                NaN              NaN
# 2743                               Taurus International         24/7 G2c
# 2744                                              Ruger       Single Six
# 2745  Glock, Inc.                                   ...  Model 30 (45 Ac
#
#      firearm_caliber           recovery_date address_geocode_type  \
# 0                9MM  2013-12-20 00:00:00+00         INTERSECTION
# 1                9MM  2011-06-11 00:00:00+00         INTERSECTION
# 2               762M  2011-05-16 00:00:00+00         INTERSECTION
# 3                38C  2012-08-03 00:00:00+00         INTERSECTION
# 4                NaN  2012-02-16 00:00:00+00         INTERSECTION
# ...              ...                     ...                  ...
# 2741             22C  2013-11-19 00:00:00+00         INTERSECTION
# 2742             40C  2012-10-26 00:00:00+00         INTERSECTION
# 2743             40C  2016-09-03 00:00:00+00         INTERSECTION
# 2744             22C  2010-09-17 00:00:00+00         INTERSECTION
# 2745             45C  2016-03-13 00:00:00+00         INTERSECTION
#
#                      recovery_block_address        city  ...  \
# 0                       N 22nd St / Bank St  Louisville  ...
# 1                7th Street Rd / Berry Blvd  Louisville  ...
# 2                       N 37th St / Bank St  Louisville  ...
# 3                     Dixie Hwy / Ralph Ave     Shively  ...
# 4                Oxmoor Ln / Shelbyville Rd     Norwood  ...
# ...                                     ...         ...  ...
# 2741                  W Pages Ln / Terry Rd  Louisville  ...
# 2742   W Southern Heights Ave / Wheeler Ave  Louisville  ...
# 2743  W Southern Heights Ave / Woodruff Ave  Louisville  ...
# 2744           Watterson Trl / Whitfield Dr  Louisville  ...
# 2745  Whisp Brook Cir / Whispering Brook Dr  Louisville  ...
#
#      person_recovered_from_race  person_recovered_from_sex  \
# 0                         Black                          M
# 1                         Black                          M
# 2                         White                          M
# 3                         Black                          M
# 4                         White                          M
# ...                         ...                        ...
# 2741                      White                          M
# 2742                      White                          M
# 2743                      White                          M
# 2744                      White                          M
# 2745                      Black                          M
#
#      person_recovered_from_age  \
# 0                         21.0
# 1                         20.0
# 2                         27.0
# 3                         53.0
# 4                         36.0
# ...                        ...
# 2741                      44.0
# 2742                      20.0
# 2743                      29.0
# 2744                      35.0
# 2745                      25.0
#
#                                          address_concat            x  \
# 0               N 22nd St / Bank St Louisville KY 40203          NaN
# 1        7th Street Rd / Berry Blvd Louisville KY 40216          NaN
# 2               N 37th St / Bank St Louisville KY 40212          NaN
# 3                     Dixie Hwy / Ralph Ave Shively KY   1195202.125
# 4           Oxmoor Ln / Shelbyville Rd Norwood KY 40222  1248916.500
# ...                                                 ...          ...
# 2741          W Pages Ln / Terry Rd Louisville KY 40258          NaN
# 2742  W Southern Heights Ave / Wheeler Ave Louisvill...  1198203.750
# 2743  W Southern Heights Ave / Woodruff Ave Louisvil...  1199311.250
# 2744   Watterson Trl / Whitfield Dr Louisville KY 40299          NaN
# 2745  Whisp Brook Cir / Whispering Brook Dr Louisvil...  1223493.625
#
#                 y  longitude   latitude  confidence  source
# 0             NaN        NaN        NaN         NaN     NaN
# 1             NaN        NaN        NaN         NaN     NaN
# 2             NaN        NaN        NaN         NaN     NaN
# 3     260851.7188 -85.799466  38.206025         NaN   LOJIC
# 4     275799.8750 -85.613325  38.249400         NaN   LOJIC
# ...           ...        ...        ...         ...     ...
# 2741          NaN        NaN        NaN         NaN     NaN
# 2742  254911.1250 -85.788676  38.189852         NaN   LOJIC
# 2743  254829.2813 -85.784819  38.189678         NaN   LOJIC
# 2744          NaN        NaN        NaN         NaN     NaN
# 2745  223231.6875 -85.698961  38.103997         NaN   LOJIC
#
# [2746 rows x 22 columns]
